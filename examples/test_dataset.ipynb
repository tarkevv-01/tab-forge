# %%
from tab_forge.dataset import Dataset
import pandas as pd

# %%
df = pd.read_csv("abalone.csv")

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Покрутим полностью зарегестрированный датасет

# %%
dataset = Dataset(
    df,
    target="Rings",
    task_type="regression",
    categorical_features=["Sex"],
    numerical_features=["Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight"])

# %%
dataset
# Out:
# Dataset(samples=4177, features=8, task='regression')

# %%
dataset.summary()
# Out:
# {'shape': (4177, 9),
#  'task_type': 'regression',
#  'target': 'Rings',
#  'n_numerical': 7,
#  'n_categorical': 1,
#  'n_unregistered': 0,
#  'missing_values': {'Sex': 0,
#   'Length': 0,
#   'Diameter': 0,
#   'Height': 0,
#   'Whole weight': 0,
#   'Shucked weight': 0,
#   'Viscera weight': 0,
#   'Shell weight': 0,
#   'Rings': 0}}

# %%
dataset.get_registered_features()
# Out:
# ['Sex',
#  'Length',
#  'Diameter',
#  'Height',
#  'Whole weight',
#  'Shucked weight',
#  'Viscera weight',
#  'Shell weight']

# %%
print("Категориальные признаки",dataset.get_categorical_features())
print("Числовые признаки",dataset.get_numerical_features())
# Out:
# Категориальные признаки ['Sex']
# Числовые признаки ['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']

# %%
dataset.get_registered_data().head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
dataset.get_registered_data().shape
# Out:
# (4177, 9)

# %% [markdown]
# Покрутим датасет с неполными зарегестрированными данными.

# %%
dataset = Dataset(
    df,
    target="Rings",
    task_type="regression",
    categorical_features=[],
    numerical_features=["Diameter", "Length", "Height", "Whole weight", "Shell weight"])

# %%
dataset
# Out:
# Dataset(samples=4177, features=8, task='regression')

# %%
dataset.summary()
# Out:
# {'shape': (4177, 9),
#  'task_type': 'regression',
#  'target': 'Rings',
#  'n_numerical': 5,
#  'n_categorical': 0,
#  'n_unregistered': 3,
#  'missing_values': {'Sex': 0,
#   'Length': 0,
#   'Diameter': 0,
#   'Height': 0,
#   'Whole weight': 0,
#   'Shucked weight': 0,
#   'Viscera weight': 0,
#   'Shell weight': 0,
#   'Rings': 0}}

# %%
dataset.get_registered_features()
# Out:
# ['Length', 'Diameter', 'Height', 'Whole weight', 'Shell weight']

# %%
print("Категориальные признаки",dataset.get_categorical_features())
print("Числовые признаки",dataset.get_numerical_features())
# Out:
# Категориальные признаки []
# Числовые признаки ['Diameter', 'Length', 'Height', 'Whole weight', 'Shell weight']

# %%
dataset.get_registered_data().shape
# Out:
# (4177, 6)

# %%
dataset.get_registered_data().head()
# Out:
#    Length  Diameter  Height  Whole weight  Shell weight  Rings
# 0   0.455     0.365   0.095        0.5140         0.150     15
# 1   0.350     0.265   0.090        0.2255         0.070      7
# 2   0.530     0.420   0.135        0.6770         0.210      9
# 3   0.440     0.365   0.125        0.5160         0.155     10
# 4   0.330     0.255   0.080        0.2050         0.055      7

# %%
dataset.get_data().shape
# Out:
# (4177, 9)

# %%
dataset.get_data().head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Поразделяем данные

# %%
train, test = dataset.train_test_split(test_size=0.2, random_state=42)

# %%
print(train)
print(test)
# Out:
# Dataset(samples=3341, features=8, task='regression')
# Dataset(samples=836, features=8, task='regression')

# %%
train.get_registered_data().head()
# Out:
#    Length  Diameter  Height  Whole weight  Shell weight  Rings
# 0   0.550     0.445   0.125        0.6720         0.210     11
# 1   0.475     0.355   0.100        0.5035         0.140      8
# 2   0.305     0.225   0.070        0.1485         0.045      7
# 3   0.275     0.200   0.065        0.1165         0.035      7
# 4   0.495     0.380   0.135        0.6295         0.215     12

# %%
test.get_registered_data().head()
# Out:
#    Length  Diameter  Height  Whole weight  Shell weight  Rings
# 0   0.605     0.455   0.160        1.1035         0.325      9
# 1   0.590     0.440   0.150        0.8725         0.245      8
# 2   0.560     0.445   0.195        0.9810         0.335     16
# 3   0.635     0.490   0.170        1.2615         0.380      9
# 4   0.475     0.385   0.145        0.6175         0.215     14
