# %%
from tab_forge.dataset import Dataset
import pandas as pd

# %%
df = pd.read_csv("abalone.csv")

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Покрутим полностью зарегестрированный датасет

# %%
dataset = Dataset(
    df,
    target="Rings",
    task_type="regression",
    categorical_features=["Sex"],
    numerical_features=["Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight"])

# %%
dataset
# Out:
# Dataset(samples=4177, features=8, task='regression')

# %%
dataset.summary()
# Out:
# {'shape': (4177, 9),
#  'task_type': 'regression',
#  'target': 'Rings',
#  'n_numerical': 7,
#  'n_categorical': 1,
#  'n_unregistered': 0,
#  'missing_values': {'Sex': 0,
#   'Length': 0,
#   'Diameter': 0,
#   'Height': 0,
#   'Whole weight': 0,
#   'Shucked weight': 0,
#   'Viscera weight': 0,
#   'Shell weight': 0,
#   'Rings': 0}}

# %%
dataset.get_registered_features()
# Out:
# ['Shucked weight',
#  'Sex',
#  'Shell weight',
#  'Height',
#  'Diameter',
#  'Length',
#  'Whole weight',
#  'Viscera weight']

# %%
print("Категориальные признаки",dataset.get_categorical_features())
print("Числовые признаки",dataset.get_numerical_features())
# Out:
# Категориальные признаки ['Sex']
# Числовые признаки ['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']

# %%
dataset.get_registered_data().head()
# Out:
#    Shucked weight Sex  Shell weight  Height  Diameter  Length  Whole weight  \
# 0          0.2245   M         0.150   0.095     0.365   0.455        0.5140
# 1          0.0995   M         0.070   0.090     0.265   0.350        0.2255
# 2          0.2565   F         0.210   0.135     0.420   0.530        0.6770
# 3          0.2155   M         0.155   0.125     0.365   0.440        0.5160
# 4          0.0895   I         0.055   0.080     0.255   0.330        0.2050
#
#    Viscera weight  Rings
# 0          0.1010     15
# 1          0.0485      7
# 2          0.1415      9
# 3          0.1140     10
# 4          0.0395      7

# %%
dataset.get_registered_data().shape
# Out:
# (4177, 9)

# %% [markdown]
# Покрутим датасет с неполными зарегестрированными данными.

# %%
dataset = Dataset(
    df,
    target="Rings",
    task_type="regression",
    categorical_features=[],
    numerical_features=["Length", "Diameter", "Height", "Whole weight", "Shell weight"])

# %%
dataset
# Out:
# Dataset(samples=4177, features=8, task='regression')

# %%
dataset.summary()
# Out:
# {'shape': (4177, 9),
#  'task_type': 'regression',
#  'target': 'Rings',
#  'n_numerical': 5,
#  'n_categorical': 0,
#  'n_unregistered': 3,
#  'missing_values': {'Sex': 0,
#   'Length': 0,
#   'Diameter': 0,
#   'Height': 0,
#   'Whole weight': 0,
#   'Shucked weight': 0,
#   'Viscera weight': 0,
#   'Shell weight': 0,
#   'Rings': 0}}

# %%
dataset.get_registered_features()
# Out:
# ['Shell weight', 'Height', 'Diameter', 'Length', 'Whole weight']

# %%
print("Категориальные признаки",dataset.get_categorical_features())
print("Числовые признаки",dataset.get_numerical_features())
# Out:
# Категориальные признаки []
# Числовые признаки ['Length', 'Diameter', 'Height', 'Whole weight', 'Shell weight']

# %%
dataset.get_registered_data().shape
# Out:
# (4177, 6)

# %%
dataset.get_registered_data().head()
# Out:
#    Shell weight  Height  Diameter  Length  Whole weight  Rings
# 0         0.150   0.095     0.365   0.455        0.5140     15
# 1         0.070   0.090     0.265   0.350        0.2255      7
# 2         0.210   0.135     0.420   0.530        0.6770      9
# 3         0.155   0.125     0.365   0.440        0.5160     10
# 4         0.055   0.080     0.255   0.330        0.2050      7

# %%
dataset.get_data().head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
dataset.get_data().shape
# Out:
# (4177, 9)
